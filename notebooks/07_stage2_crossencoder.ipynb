# %% [markdown]
# # Stage 2 Cross-Encoder
#
# ペア単位の精密スコアリングによる二次スクリーニング。
#
# ---
#
# *TODO: 実装を進める*

# %%
# Setup
import json
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
DATA_DIR = PROJECT_ROOT / 'data'
print(f'Project root: {PROJECT_ROOT}')
