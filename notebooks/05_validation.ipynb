# %% [markdown]
# # データ品質検証
#
# 仕様書5.2の品質基準に基づき、生成データのバリデーションを実施する。
#
# ---
#
# *TODO: 実装を進める*

# %%
# Setup
import json
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
DATA_DIR = PROJECT_ROOT / 'data'
print(f'Project root: {PROJECT_ROOT}')
