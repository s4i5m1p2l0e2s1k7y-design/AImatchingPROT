# %% [markdown]
# # Stage 3 LLMマルチエージェント
#
# 5エージェントによる多角評価・議論・提案資料生成。
#
# ---
#
# *TODO: 実装を進める*

# %%
# Setup
import json
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
DATA_DIR = PROJECT_ROOT / 'data'
print(f'Project root: {PROJECT_ROOT}')
