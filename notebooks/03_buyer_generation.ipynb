# %% [markdown]
# # 買い手データ生成（10,000件）
#
# 仕様書2.3に基づき、買い手候補10,000件のテストデータを生成する。
#
# ---
#
# *TODO: 実装を進める*

# %%
# Setup
import json
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
DATA_DIR = PROJECT_ROOT / 'data'
print(f'Project root: {PROJECT_ROOT}')
