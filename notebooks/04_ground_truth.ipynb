# %% [markdown]
# # 正解データの設計
#
# 仕様書2.4に基づき、A/B/C/D判定の正解ペア500件を設計する。
#
# ---
#
# *TODO: 実装を進める*

# %%
# Setup
import json
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
DATA_DIR = PROJECT_ROOT / 'data'
print(f'Project root: {PROJECT_ROOT}')
