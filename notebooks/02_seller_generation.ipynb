# %% [markdown]
# # 売り手データ生成（2,000社）
#
# 仕様書2.2に基づき、売り手企業2,000社のテストデータを生成する。
#
# ---
#
# *TODO: 実装を進める*

# %%
# Setup
import json
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
DATA_DIR = PROJECT_ROOT / 'data'
print(f'Project root: {PROJECT_ROOT}')
